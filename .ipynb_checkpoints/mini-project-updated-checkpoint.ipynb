# %% [markdown]
# # Mini-project

# %% [markdown]
# ## General guidelines
#
# We want to make a typical study of a ML problem.
#
# We're going to use Fashion-MNIST ("*fashion-mnist-reshaped.npz*")  as data set, attempting to classify the pictures correctly.
#
# There are 2 parts in the project:
# - use `DecisionTreeClassifier` and PCA from sklearn to classify the data
# - make your own multi-class classifier, deriving its updates from scratch
# The first part weights more in the total grade than the second one.
#
# In the first part, the goal is to showcase a typical hyper-parameter tuning. We will simulate the fact of having different tasks by restricting ourselves to different dataset size, and comment on how hyper-parameters choice can depend a lot on how much data we have at hand.
#
# General advice: **write clean code**, well factored in functions/classes, for each question, as much as possible.
# This will make your code **easier to read and also easier to run!**. You may re-use code in several questions. If it's  well factored, it will be easier to code the next questions.
#
# Tips: you may want to use
# - `sklearn.tree.DecisionTreeClassifier`
# - `sklearn.model_selection.train_test_split`
# - `sklearn.decomposition.PCA`
# - `sklearn.model_selection.cross_validate`
#
# to lighten your code.

# %% [markdown]
# ## Part 1: using `sklearn.tree.DecisionTreeClassifier`
#
# ## (about 15 points over 20 total)
#
# Decision Trees are powerful methods, however they can easily overfit. The number of parameters in the model essenitially grows like $\sim O(2^{maxDepth})$, i.e. exponentially with the depth of the tree.
#
# ### Part 1.1: `Ntrain+Nval=1000, Nvalid=1000, Ntest=10000`
#
# In this part we use this amount of data.
# - import the data, split the "train+validation" sets. Keep the test set for the **very** end.
# - attempt direct classification using a `sklearn.tree.DecisionTreeClassifier`. Optimize the hyper-parameter `max_depth`. Measure and store the validation accuracy for the best choice of `max_depth`.
# Do you fear you may be overfitting ? Explain your answer.
# - Now, let's add some PCA as pre-processing.
#     - Using `max_depth=5`, what is the best number of PCA components (nComp_PCA) to keep ? Hint: you may use something like `nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])` as the range of nComp_PCA values to be explored.
#     - Using `max_depth=12`, what is the best number of PCA components (nComp_PCA) to keep ?
#     - Can you explain why this optimal number changes with depth ?
# - Find the best (max_depth, nComp_PCA) pair.
# - Can you explain the behavior of the optimal `max_depth`, let's call it $m*$, with `nComp_PCA`, at **small** `nComp_PCA` ?
# - Can you explain the behavior of the optimal `max_depth`, let's call it $m*$, with `nComp_PCA`, at **large** `nComp_PCA` ?
# - Measure the cross-validation error for this best pair. Are you surprised with the result?

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
LoadObject = np.load("C:/Users/dadinho/Desktop/projet/fashion-mnist-reshaped.npz") # please put your data over there so it's easy for me to run your code
linearPictureLength = 28
X = LoadObject['train_images']
y = LoadObject['train_labels']
## we do not use the TEST SET for now:
# Xtest = LoadObject['test_images']
# ytest = LoadObject['test_labels']
ratio_train = 0.016667
ratio_valid = 0.016667
ratio_test = 0.16667

# %%
def split1(X, ratio_train, ratio_valid,ratio_test):
   

    Ntot   = X.shape[0]
    Ntrain = int(ratio_train*Ntot)
    Nvalid = int(ratio_valid*Ntot)
    Ntest  = int(ratio_test*Ntot)
    X_train = X[0: Ntrain].copy()
    y_train = y[0: Ntrain].copy()
    X_valid = X[Ntrain:Ntrain+Nvalid].copy() 
    y_valid = y[Ntrain:Ntrain+Nvalid].copy() 
    return X_train, y_train, X_valid, y_valid,Ntest

# %%
X_train, y_train, X_valid, y_valid,n = split1(X, ratio_train, ratio_valid,ratio_test)
print(X_train.shape)
print(X_valid.shape)
print(n)
# Out:
# (2000, 784)
# (2000, 784)
# 10000

# %%
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
for nC in max_depth:
    clf=DecisionTreeClassifier(random_state=123,max_depth=nC)
    clf.fit(X_train, y_train)
    trainscore = clf.score(X_train,y_train)
    validscore = clf.score(X_valid,y_valid)
    print("nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
# Out:
# nombre Composants 10    training score: 0.9525 . valid score: 0.7045
# nombre Composants 20    training score: 1.0 . valid score: 0.6985
# nombre Composants 30    training score: 1.0 . valid score: 0.6985
# nombre Composants 40    training score: 1.0 . valid score: 0.6985
# nombre Composants 50    training score: 1.0 . valid score: 0.6985
# nombre Composants 60    training score: 1.0 . valid score: 0.6985
# nombre Composants 70    training score: 1.0 . valid score: 0.6985
# nombre Composants 80    training score: 1.0 . valid score: 0.6985
# nombre Composants 90    training score: 1.0 . valid score: 0.6985
# nombre Composants 100    training score: 1.0 . valid score: 0.6985
# nombre Composants 110    training score: 1.0 . valid score: 0.6985
# nombre Composants None    training score: 1.0 . valid score: 0.6985

# %%
    clf = DecisionTreeClassifier(random_state=123,max_depth=10)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_valid)
    score = balanced_accuracy_score(y_valid, y_pred)  # scoring
    print("Balanced accuracy score: {}".format(score))
# Out:
# Balanced accuracy score: 0.7046193385247219

# %%
nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])
t=[]
v=[]
for nC in nComp_range:
    ## pre-processing 
    preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
    preProc.fit(X_train)
    X_train_Transformed = preProc.transform(X_train)
    X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data
    clf = DecisionTreeClassifier(random_state=123,max_depth=5)
    clf.fit(X_train_Transformed, y_train)
    trainscore = clf.score(X_train_Transformed,y_train)
    validscore = clf.score(X_valid_Transformed,y_valid)
    t.append(trainscore)
    v.append(validscore)
    print("nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
print(max(t))
print(max(v))
# Out:
# nombre Composants 1    training score: 0.354 . valid score: 0.3125
# nombre Composants 2    training score: 0.551 . valid score: 0.5115
# nombre Composants 3    training score: 0.618 . valid score: 0.5705
# nombre Composants 4    training score: 0.649 . valid score: 0.611
# nombre Composants 5    training score: 0.654 . valid score: 0.61
# nombre Composants 6    training score: 0.6715 . valid score: 0.625
# nombre Composants 7    training score: 0.6715 . valid score: 0.6275
# nombre Composants 8    training score: 0.634 . valid score: 0.5905
# nombre Composants 9    training score: 0.6335 . valid score: 0.5945
# nombre Composants 10    training score: 0.639 . valid score: 0.5905
# nombre Composants 11    training score: 0.639 . valid score: 0.591
# nombre Composants 12    training score: 0.6395 . valid score: 0.592
# nombre Composants 13    training score: 0.6385 . valid score: 0.59
# nombre Composants 14    training score: 0.6385 . valid score: 0.5895
# nombre Composants 15    training score: 0.639 . valid score: 0.5855
# nombre Composants 16    training score: 0.639 . valid score: 0.5885
# nombre Composants 17    training score: 0.639 . valid score: 0.584
# nombre Composants 18    training score: 0.639 . valid score: 0.587
# nombre Composants 19    training score: 0.639 . valid score: 0.5895
# nombre Composants 20    training score: 0.639 . valid score: 0.5905
# nombre Composants 21    training score: 0.6415 . valid score: 0.5855
# nombre Composants 22    training score: 0.6425 . valid score: 0.583
# nombre Composants 23    training score: 0.643 . valid score: 0.5855
# nombre Composants 24    training score: 0.6425 . valid score: 0.5845
# nombre Composants 25    training score: 0.6435 . valid score: 0.5855
# nombre Composants 26    training score: 0.6435 . valid score: 0.5865
# nombre Composants 27    training score: 0.6435 . valid score: 0.5855
# nombre Composants 28    training score: 0.6435 . valid score: 0.5875
# nombre Composants 29    training score: 0.643 . valid score: 0.5865
# nombre Composants 30    training score: 0.6435 . valid score: 0.585
# nombre Composants 31    training score: 0.6435 . valid score: 0.5865
# nombre Composants 32    training score: 0.6435 . valid score: 0.587
# nombre Composants 33    training score: 0.6435 . valid score: 0.588
# nombre Composants 34    training score: 0.6435 . valid score: 0.5865
# nombre Composants 35    training score: 0.6435 . valid score: 0.584
# nombre Composants 36    training score: 0.6435 . valid score: 0.588
# nombre Composants 37    training score: 0.643 . valid score: 0.5875
# nombre Composants 38    training score: 0.6425 . valid score: 0.5825
# nombre Composants 39    training score: 0.6435 . valid score: 0.5825
# nombre Composants 40    training score: 0.6435 . valid score: 0.582
# nombre Composants 41    training score: 0.6435 . valid score: 0.5865
# nombre Composants 42    training score: 0.645 . valid score: 0.586
# nombre Composants 43    training score: 0.645 . valid score: 0.585
# nombre Composants 44    training score: 0.6435 . valid score: 0.5835
# nombre Composants 45    training score: 0.645 . valid score: 0.583
# nombre Composants 46    training score: 0.6435 . valid score: 0.5825
# nombre Composants 47    training score: 0.645 . valid score: 0.5855
# nombre Composants 48    training score: 0.645 . valid score: 0.5855
# nombre Composants 49    training score: 0.645 . valid score: 0.5855
# nombre Composants 50    training score: 0.6435 . valid score: 0.583
# nombre Composants 100    training score: 0.646 . valid score: 0.5875
# nombre Composants 200    training score: 0.6455 . valid score: 0.5845
# nombre Composants 400    training score: 0.6465 . valid score: 0.58
# nombre Composants 783    training score: 0.647 . valid score: 0.5695
# nombre Composants 784    training score: 0.647 . valid score: 0.5755
# 0.6715
# 0.6275

# %%
nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])
t=[]
v=[]
for nC in nComp_range:
    ## pre-processing 
    preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
    preProc.fit(X_train)
    X_train_Transformed = preProc.transform(X_train)
    X_valid_Transformed = preProc.transform(X_valid) 
    clf = DecisionTreeClassifier(random_state=123,max_depth=12)
    clf.fit(X_train_Transformed, y_train)
    trainscore = clf.score(X_train_Transformed,y_train)
    validscore = clf.score(X_valid_Transformed,y_valid)
    t.append(trainscore)
    v.append(validscore)
    print("nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
print(max(t))
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])
L=[]
for nC in nComp_range:

       for mp in max_depth:
                ## pre-processing 
                    preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
                    preProc.fit(X_train)
                    X_train_Transformed = preProc.transform(X_train)
                    X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

                ## classification
                    clf = DecisionTreeClassifier(random_state=123,max_depth=mp)
                    clf.fit(X_train_Transformed, y_train)

                ## measure of performance
                    trainscore = clf.score(X_train_Transformed,y_train)
                    validscore = clf.score(X_valid_Transformed,y_valid)
                    L.append( validscore)
                    print("max_depth", mp ,"nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
# Out:
# max_depth 10 nombre Composants 1    training score: 0.452 . valid score: 0.304
# max_depth 20 nombre Composants 1    training score: 0.871 . valid score: 0.243
# max_depth 30 nombre Composants 1    training score: 0.9845 . valid score: 0.2275
# max_depth 40 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 50 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 60 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 70 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 80 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 90 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 100 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 110 nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth None nombre Composants 1    training score: 1.0 . valid score: 0.225
# max_depth 10 nombre Composants 2    training score: 0.721 . valid score: 0.516
# max_depth 20 nombre Composants 2    training score: 0.954 . valid score: 0.4725
# max_depth 30 nombre Composants 2    training score: 0.9985 . valid score: 0.4685
# max_depth 40 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 50 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 60 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 70 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 80 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 90 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 100 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 110 nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth None nombre Composants 2    training score: 1.0 . valid score: 0.468
# max_depth 10 nombre Composants 3    training score: 0.7845 . valid score: 0.567
# max_depth 20 nombre Composants 3    training score: 0.994 . valid score: 0.5405
# max_depth 30 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 40 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 50 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 60 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 70 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 80 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 90 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 100 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 110 nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth None nombre Composants 3    training score: 1.0 . valid score: 0.5435
# max_depth 10 nombre Composants 4    training score: 0.8305 . valid score: 0.6285
# max_depth 20 nombre Composants 4    training score: 0.9985 . valid score: 0.603
# max_depth 30 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 40 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 50 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 60 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 70 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 80 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 90 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 100 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 110 nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth None nombre Composants 4    training score: 1.0 . valid score: 0.6065
# max_depth 10 nombre Composants 5    training score: 0.8375 . valid score: 0.655
# max_depth 20 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 30 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 40 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 50 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 60 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 70 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 80 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 90 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 100 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 110 nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth None nombre Composants 5    training score: 1.0 . valid score: 0.6195
# max_depth 10 nombre Composants 6    training score: 0.868 . valid score: 0.667
# max_depth 20 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 30 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 40 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 50 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 60 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 70 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 80 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 90 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 100 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 110 nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth None nombre Composants 6    training score: 1.0 . valid score: 0.6525
# max_depth 10 nombre Composants 7    training score: 0.874 . valid score: 0.669
# max_depth 20 nombre Composants 7    training score: 0.999 . valid score: 0.6515
# max_depth 30 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 40 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 50 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 60 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 70 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 80 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 90 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 100 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 110 nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth None nombre Composants 7    training score: 1.0 . valid score: 0.652
# max_depth 10 nombre Composants 8    training score: 0.844 . valid score: 0.674
# max_depth 20 nombre Composants 8    training score: 0.9995 . valid score: 0.665
# max_depth 30 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 40 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 50 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 60 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 70 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 80 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 90 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 100 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 110 nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth None nombre Composants 8    training score: 1.0 . valid score: 0.6615
# max_depth 10 nombre Composants 9    training score: 0.8435 . valid score: 0.6735
# max_depth 20 nombre Composants 9    training score: 0.9995 . valid score: 0.676
# max_depth 30 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 40 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 50 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 60 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 70 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 80 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 90 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 100 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 110 nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth None nombre Composants 9    training score: 1.0 . valid score: 0.6865
# max_depth 10 nombre Composants 10    training score: 0.85 . valid score: 0.671
# max_depth 20 nombre Composants 10    training score: 0.998 . valid score: 0.6715
# max_depth 30 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 40 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 50 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 60 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 70 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 80 nombre Composants 10    training score: 1.0 . valid score: 0.6725
# max_depth 50 nombre Composants 14    training score: 1.0 . valid score: 0.6875
# max_depth 60 nombre Composants 14    training score: 1.0 . valid score: 0.6745
# max_depth 70 nombre Composants 14    training score: 1.0 . valid score: 0.687
# max_depth 80 nombre Composants 14    training score: 1.0 . valid score: 0.6875
# max_depth 90 nombre Composants 14    training score: 1.0 . valid score: 0.688
# max_depth 100 nombre Composants 14    training score: 1.0 . valid score: 0.688
# max_depth 110 nombre Composants 14    training score: 1.0 . valid score: 0.6875
# max_depth None nombre Composants 14    training score: 1.0 . valid score: 0.688
# max_depth 10 nombre Composants 15    training score: 0.8635 . valid score: 0.671
# max_depth 20 nombre Composants 15    training score: 0.9955 . valid score: 0.675
# max_depth 30 nombre Composants 15    training score: 1.0 . valid score: 0.667
# max_depth 40 nombre Composants 15    training score: 1.0 . valid score: 0.668
# max_depth 50 nombre Composants 15    training score: 1.0 . valid score: 0.6675
# max_depth 60 nombre Composants 15    training score: 1.0 . valid score: 0.6725
# max_depth 70 nombre Composants 15    training score: 1.0 . valid score: 0.6725
# max_depth 80 nombre Composants 15    training score: 1.0 . valid score: 0.668
# max_depth 90 nombre Composants 15    training score: 1.0 . valid score: 0.6665
# max_depth 100 nombre Composants 15    training score: 1.0 . valid score: 0.666
# max_depth 110 nombre Composants 15    training score: 1.0 . valid score: 0.6605
# max_depth None nombre Composants 15    training score: 1.0 . valid score: 0.674
# max_depth 10 nombre Composants 16    training score: 0.8635 . valid score: 0.6745
# max_depth 20 nombre Composants 16    training score: 0.9985 . valid score: 0.682
# max_depth 30 nombre Composants 16    training score: 1.0 . valid score: 0.675
# max_depth 40 nombre Composants 16    training score: 1.0 . valid score: 0.676
# max_depth 50 nombre Composants 16    training score: 1.0 . valid score: 0.6815
# max_depth 60 nombre Composants 16    training score: 1.0 . valid score: 0.6805
# max_depth 70 nombre Composants 16    training score: 1.0 . valid score: 0.676
# max_depth 80 nombre Composants 16    training score: 1.0 . valid score: 0.676
# max_depth 90 nombre Composants 16    training score: 1.0 . valid score: 0.684
# max_depth 100 nombre Composants 16    training score: 1.0 . valid score: 0.6765
# max_depth 110 nombre Composants 16    training score: 1.0 . valid score: 0.6795
# max_depth None nombre Composants 16    training score: 1.0 . valid score: 0.686
# max_depth 10 nombre Composants 17    training score: 0.863 . valid score: 0.679
# max_depth 20 nombre Composants 17    training score: 0.999 . valid score: 0.6875
# max_depth 30 nombre Composants 17    training score: 1.0 . valid score: 0.6845
# max_depth 40 nombre Composants 17    training score: 1.0 . valid score: 0.684
# max_depth 50 nombre Composants 17    training score: 1.0 . valid score: 0.6785
# max_depth 60 nombre Composants 17    training score: 1.0 . valid score: 0.679
# max_depth 70 nombre Composants 17    training score: 1.0 . valid score: 0.6825
# max_depth 80 nombre Composants 17    training score: 1.0 . valid score: 0.681
# max_depth 90 nombre Composants 17    training score: 1.0 . valid score: 0.686
# max_depth 100 nombre Composants 17    training score: 1.0 . valid score: 0.6735
# max_depth 110 nombre Composants 17    training score: 1.0 . valid score: 0.6855
# max_depth None nombre Composants 17    training score: 1.0 . valid score: 0.6755
# max_depth 10 nombre Composants 18    training score: 0.866 . valid score: 0.6875
# max_depth 20 nombre Composants 18    training score: 0.999 . valid score: 0.682
# max_depth 30 nombre Composants 18    training score: 1.0 . valid score: 0.6775
# max_depth 40 nombre Composants 18    training score: 1.0 . valid score: 0.681
# max_depth 50 nombre Composants 18    training score: 1.0 . valid score: 0.684
# max_depth 60 nombre Composants 18    training score: 1.0 . valid score: 0.696
# max_depth 70 nombre Composants 18    training score: 1.0 . valid score: 0.687
# max_depth 80 nombre Composants 18    training score: 1.0 . valid score: 0.6845
# max_depth 90 nombre Composants 18    training score: 1.0 . valid score: 0.682
# max_depth 100 nombre Composants 18    training score: 1.0 . valid score: 0.6835
# max_depth 110 nombre Composants 18    training score: 1.0 . valid score: 0.6875
# max_depth None nombre Composants 18    training score: 1.0 . valid score: 0.689
# max_depth 10 nombre Composants 19    training score: 0.8665 . valid score: 0.6805
# max_depth 20 nombre Composants 19    training score: 0.9995 . valid score: 0.6845
# max_depth 30 nombre Composants 19    training score: 1.0 . valid score: 0.6805
# max_depth 40 nombre Composants 19    training score: 1.0 . valid score: 0.676
# max_depth 50 nombre Composants 19    training score: 1.0 . valid score: 0.6795
# max_depth 60 nombre Composants 19    training score: 1.0 . valid score: 0.6775
# max_depth 70 nombre Composants 19    training score: 1.0 . valid score: 0.683
# max_depth 80 nombre Composants 19    training score: 1.0 . valid score: 0.6875
# max_depth 90 nombre Composants 19    training score: 1.0 . valid score: 0.6845
# max_depth 100 nombre Composants 19    training score: 1.0 . valid score: 0.682
# max_depth 110 nombre Composants 19    training score: 1.0 . valid score: 0.677
# max_depth None nombre Composants 19    training score: 1.0 . valid score: 0.6795
# max_depth 10 nombre Composants 20    training score: 0.868 . valid score: 0.6835
# max_depth 20 nombre Composants 20    training score: 0.999 . valid score: 0.684
# max_depth 30 nombre Composants 20    training score: 1.0 . valid score: 0.6915
# max_depth 40 nombre Composants 20    training score: 1.0 . valid score: 0.688
# max_depth 50 nombre Composants 20    training score: 1.0 . valid score: 0.6915
# max_depth 60 nombre Composants 20    training score: 1.0 . valid score: 0.683
# max_depth 70 nombre Composants 20    training score: 1.0 . valid score: 0.6885
# max_depth 80 nombre Composants 20    training score: 1.0 . valid score: 0.689
# max_depth 90 nombre Composants 20    training score: 1.0 . valid score: 0.68
# max_depth 100 nombre Composants 20    training score: 1.0 . valid score: 0.687
# max_depth 110 nombre Composants 20    training score: 1.0 . valid score: 0.6865
# max_depth None nombre Composants 20    training score: 1.0 . valid score: 0.691
# max_depth 10 nombre Composants 21    training score: 0.867 . valid score: 0.6785
# max_depth 20 nombre Composants 21    training score: 1.0 . valid score: 0.6825
# max_depth 30 nombre Composants 21    training score: 1.0 . valid score: 0.676
# max_depth 40 nombre Composants 21    training score: 1.0 . valid score: 0.6775
# max_depth 50 nombre Composants 21    training score: 1.0 . valid score: 0.6875
# max_depth 60 nombre Composants 21    training score: 1.0 . valid score: 0.676
# max_depth 30 nombre Composants 25    training score: 1.0 . valid score: 0.6815
# max_depth 40 nombre Composants 25    training score: 1.0 . valid score: 0.672
# max_depth 50 nombre Composants 25    training score: 1.0 . valid score: 0.6815
# max_depth 60 nombre Composants 25    training score: 1.0 . valid score: 0.683
# max_depth 70 nombre Composants 25    training score: 1.0 . valid score: 0.678
# max_depth 80 nombre Composants 25    training score: 1.0 . valid score: 0.681
# max_depth 90 nombre Composants 25    training score: 1.0 . valid score: 0.681
# max_depth 100 nombre Composants 25    training score: 1.0 . valid score: 0.674
# max_depth 110 nombre Composants 25    training score: 1.0 . valid score: 0.6815
# max_depth None nombre Composants 25    training score: 1.0 . valid score: 0.6775
# max_depth 10 nombre Composants 26    training score: 0.8685 . valid score: 0.6825
# max_depth 20 nombre Composants 26    training score: 1.0 . valid score: 0.684
# max_depth 30 nombre Composants 26    training score: 1.0 . valid score: 0.6745
# max_depth 40 nombre Composants 26    training score: 1.0 . valid score: 0.6785
# max_depth 50 nombre Composants 26    training score: 1.0 . valid score: 0.6725
# max_depth 60 nombre Composants 26    training score: 1.0 . valid score: 0.667
# max_depth 70 nombre Composants 26    training score: 1.0 . valid score: 0.672
# max_depth 80 nombre Composants 26    training score: 1.0 . valid score: 0.681
# max_depth 90 nombre Composants 26    training score: 1.0 . valid score: 0.68
# max_depth 100 nombre Composants 26    training score: 1.0 . valid score: 0.6655
# max_depth 110 nombre Composants 26    training score: 1.0 . valid score: 0.6785
# max_depth None nombre Composants 26    training score: 1.0 . valid score: 0.675
# max_depth 10 nombre Composants 27    training score: 0.869 . valid score: 0.683
# max_depth 20 nombre Composants 27    training score: 1.0 . valid score: 0.6765
# max_depth 30 nombre Composants 27    training score: 1.0 . valid score: 0.677
# max_depth 40 nombre Composants 27    training score: 1.0 . valid score: 0.677
# max_depth 50 nombre Composants 27    training score: 1.0 . valid score: 0.6775
# max_depth 60 nombre Composants 27    training score: 1.0 . valid score: 0.68
# max_depth 70 nombre Composants 27    training score: 1.0 . valid score: 0.679
# max_depth 80 nombre Composants 27    training score: 1.0 . valid score: 0.677
# max_depth 90 nombre Composants 27    training score: 1.0 . valid score: 0.6815
# max_depth 100 nombre Composants 27    training score: 1.0 . valid score: 0.677
# max_depth 110 nombre Composants 27    training score: 1.0 . valid score: 0.678
# max_depth None nombre Composants 27    training score: 1.0 . valid score: 0.68
# max_depth 10 nombre Composants 28    training score: 0.8685 . valid score: 0.684
# max_depth 20 nombre Composants 28    training score: 0.999 . valid score: 0.6865
# max_depth 30 nombre Composants 28    training score: 1.0 . valid score: 0.6845
# max_depth 40 nombre Composants 28    training score: 1.0 . valid score: 0.674
# max_depth 50 nombre Composants 28    training score: 1.0 . valid score: 0.685
# max_depth 60 nombre Composants 28    training score: 1.0 . valid score: 0.6735
# max_depth 70 nombre Composants 28    training score: 1.0 . valid score: 0.6785
# max_depth 80 nombre Composants 28    training score: 1.0 . valid score: 0.686
# max_depth 90 nombre Composants 28    training score: 1.0 . valid score: 0.6785
# max_depth 60 nombre Composants 50    training score: 1.0 . valid score: 0.6765
# max_depth 70 nombre Composants 50    training score: 1.0 . valid score: 0.674
# max_depth 80 nombre Composants 50    training score: 1.0 . valid score: 0.677
# max_depth 90 nombre Composants 50    training score: 1.0 . valid score: 0.6705
# max_depth 100 nombre Composants 50    training score: 1.0 . valid score: 0.671
# max_depth 110 nombre Composants 50    training score: 1.0 . valid score: 0.6625
# max_depth None nombre Composants 50    training score: 1.0 . valid score: 0.6765
# max_depth 10 nombre Composants 100    training score: 0.879 . valid score: 0.6645
# max_depth 20 nombre Composants 100    training score: 0.9995 . valid score: 0.659
# max_depth 30 nombre Composants 100    training score: 1.0 . valid score: 0.6555
# max_depth 40 nombre Composants 100    training score: 1.0 . valid score: 0.667
# max_depth 50 nombre Composants 100    training score: 1.0 . valid score: 0.6625
# max_depth 60 nombre Composants 100    training score: 1.0 . valid score: 0.658
# max_depth 70 nombre Composants 100    training score: 1.0 . valid score: 0.6585
# max_depth 80 nombre Composants 100    training score: 1.0 . valid score: 0.652
# max_depth 90 nombre Composants 100    training score: 1.0 . valid score: 0.6455
# max_depth 100 nombre Composants 100    training score: 1.0 . valid score: 0.6605
# max_depth 110 nombre Composants 100    training score: 1.0 . valid score: 0.6665
# max_depth None nombre Composants 100    training score: 1.0 . valid score: 0.6735
# max_depth 10 nombre Composants 200    training score: 0.88 . valid score: 0.6625
# max_depth 20 nombre Composants 200    training score: 1.0 . valid score: 0.65
# max_depth 30 nombre Composants 200    training score: 1.0 . valid score: 0.651
# max_depth 40 nombre Composants 200    training score: 1.0 . valid score: 0.657
# max_depth 50 nombre Composants 200    training score: 1.0 . valid score: 0.6585
# max_depth 60 nombre Composants 200    training score: 1.0 . valid score: 0.659
# max_depth 70 nombre Composants 200    training score: 1.0 . valid score: 0.6475
# max_depth 80 nombre Composants 200    training score: 1.0 . valid score: 0.6545
# max_depth 90 nombre Composants 200    training score: 1.0 . valid score: 0.648
# max_depth 100 nombre Composants 200    training score: 1.0 . valid score: 0.6575
# max_depth 110 nombre Composants 200    training score: 1.0 . valid score: 0.6455
# max_depth None nombre Composants 200    training score: 1.0 . valid score: 0.653
# max_depth 10 nombre Composants 400    training score: 0.8805 . valid score: 0.655
# max_depth 20 nombre Composants 400    training score: 1.0 . valid score: 0.642
# max_depth 30 nombre Composants 400    training score: 1.0 . valid score: 0.645
# max_depth 40 nombre Composants 400    training score: 1.0 . valid score: 0.6315
# max_depth 50 nombre Composants 400    training score: 1.0 . valid score: 0.6345
# max_depth 60 nombre Composants 400    training score: 1.0 . valid score: 0.6375
# max_depth 70 nombre Composants 400    training score: 1.0 . valid score: 0.638
# max_depth 80 nombre Composants 400    training score: 1.0 . valid score: 0.646
# max_depth 90 nombre Composants 400    training score: 1.0 . valid score: 0.6395
# max_depth 100 nombre Composants 400    training score: 1.0 . valid score: 0.632
# max_depth 110 nombre Composants 400    training score: 1.0 . valid score: 0.6315
# max_depth None nombre Composants 400    training score: 1.0 . valid score: 0.6415
# max_depth 10 nombre Composants 783    training score: 0.881 . valid score: 0.6135
# max_depth 20 nombre Composants 783    training score: 0.998 . valid score: 0.596
# max_depth 30 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 40 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 50 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 60 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 70 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 80 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 90 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 100 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 110 nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth None nombre Composants 783    training score: 1.0 . valid score: 0.588
# max_depth 10 nombre Composants 784    training score: 0.881 . valid score: 0.6215
# max_depth 20 nombre Composants 784    training score: 0.997 . valid score: 0.593
# max_depth 30 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 40 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 50 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 60 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 70 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 80 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 90 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 100 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth 110 nombre Composants 784    training score: 1.0 . valid score: 0.588
# max_depth None nombre Composants 784    training score: 1.0 . valid score: 0.588

# %%
res1 = max(L) 

  
# printing result  
print ("The indices wise maximum number : " +  str(res1))
# Out:
# The indices wise maximum number : 0.696

# %%
        preProc = sklearn.decomposition.PCA(n_components=18, copy=True)
        preProc.fit(X_train)
        X_train_Transformed = preProc.transform(X_train)
        X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

        ## classification
        clf = DecisionTreeClassifier(random_state=123,max_depth=60)
        clf.fit(X_train_Transformed, y_train)

        ## measure of performance
        scores = cross_val_score(clf, X_valid_Transformed, y_valid)
        print(scores)
        print("mean: {:.3f} (std: {:.3f})".format(scores.mean(),
                                                  scores.std()),
              end="\n\n")
# Out:
# [0.6625 0.695  0.6825 0.675  0.7125]
# mean: 0.685 (std: 0.017)

# %% [markdown]
# ### Part 1.2: `Ntrain+Nval=2000, Nvalid=2000`
#
# If you factored your code decently in the last questions, this should be very easy/fast to do. Ideally, it should be a couple of lines and a single function call. (For the core computation, excluding plots and presentation)
# - split the "train+validation" sets.
# - Find the best (max_depth, nComp_PCA) pair.
# - Measure the cross-validation error for this best pair. Are you surprised with the result?

# %%
ratio_train= 0.0333339
ratio_valid= 0.0333339
X_train, y_train, X_valid, y_valid,n = split1(X, ratio_train, ratio_valid,ratio_test)
print(X_train.shape)
print(X_valid.shape)
# Out:
# (2000, 784)
# (2000,)
# (2000, 784)

# %%
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])
L=[]
for nC in nComp_range:

       for mp in max_depth:
                ## pre-processing 
                    preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
                    preProc.fit(X_train)
                    X_train_Transformed = preProc.transform(X_train)
                    X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

                ## classification
                    clf = DecisionTreeClassifier(random_state=123,max_depth=mp)
                    clf.fit(X_train_Transformed, y_train)

                ## measure of performance
                    trainscore = clf.score(X_train_Transformed,y_train)
                    validscore = clf.score(X_valid_Transformed,y_valid)
                    L.append( validscore)
                    print("max_depth", mp ,"nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
# Out:
# max_depth 10 nombre Composants 1    training score: 0.35005 . valid score: 0.2928
# max_depth 20 nombre Composants 1    training score: 0.5897 . valid score: 0.2589
# max_depth 30 nombre Composants 1    training score: 0.84595 . valid score: 0.2331
# max_depth 40 nombre Composants 1    training score: 0.97395 . valid score: 0.2201
# max_depth 50 nombre Composants 1    training score: 0.9986 . valid score: 0.2192
# max_depth 60 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 70 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 80 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 90 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 100 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 110 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth None nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth 10 nombre Composants 2    training score: 0.60295 . valid score: 0.5302
# max_depth 20 nombre Composants 2    training score: 0.86975 . valid score: 0.4637
# max_depth 30 nombre Composants 2    training score: 0.9835 . valid score: 0.4457
# max_depth 40 nombre Composants 2    training score: 0.9996 . valid score: 0.4415
# max_depth 50 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 60 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 70 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 80 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 90 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 100 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 110 nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth None nombre Composants 2    training score: 1.0 . valid score: 0.4443
# max_depth 10 nombre Composants 3    training score: 0.6855 . valid score: 0.6194
# max_depth 20 nombre Composants 3    training score: 0.92805 . valid score: 0.5811
# max_depth 30 nombre Composants 3    training score: 0.9975 . valid score: 0.562
# max_depth 40 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 50 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 60 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 70 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 80 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 90 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 100 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 110 nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth None nombre Composants 3    training score: 1.0 . valid score: 0.5643
# max_depth 10 nombre Composants 4    training score: 0.73555 . valid score: 0.6723
# max_depth 20 nombre Composants 4    training score: 0.96285 . valid score: 0.6446
# max_depth 30 nombre Composants 4    training score: 0.9981 . valid score: 0.6426
# max_depth 40 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 50 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 60 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 70 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 80 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 90 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 100 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 110 nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth None nombre Composants 4    training score: 1.0 . valid score: 0.6424
# max_depth 10 nombre Composants 5    training score: 0.7529 . valid score: 0.6886
# max_depth 20 nombre Composants 5    training score: 0.97225 . valid score: 0.668
# max_depth 30 nombre Composants 5    training score: 0.99965 . valid score: 0.6624
# max_depth 40 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 50 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 60 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 70 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 80 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 90 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 100 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 110 nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth None nombre Composants 5    training score: 1.0 . valid score: 0.662
# max_depth 10 nombre Composants 6    training score: 0.7633 . valid score: 0.7009
# max_depth 20 nombre Composants 6    training score: 0.9622 . valid score: 0.6941
# max_depth 30 nombre Composants 6    training score: 0.99685 . valid score: 0.6872
# max_depth 40 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 50 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 60 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 70 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 80 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 90 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 100 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 110 nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth None nombre Composants 6    training score: 1.0 . valid score: 0.6863
# max_depth 10 nombre Composants 7    training score: 0.7654 . valid score: 0.7083
# max_depth 20 nombre Composants 7    training score: 0.9598 . valid score: 0.7077
# max_depth 30 nombre Composants 7    training score: 0.99785 . valid score: 0.6961
# max_depth 40 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 50 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 60 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 70 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 80 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 90 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 100 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 110 nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth None nombre Composants 7    training score: 1.0 . valid score: 0.6952
# max_depth 10 nombre Composants 8    training score: 0.76965 . valid score: 0.7161
# max_depth 20 nombre Composants 8    training score: 0.95665 . valid score: 0.724
# max_depth 30 nombre Composants 8    training score: 0.9996 . valid score: 0.7112
# max_depth 40 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 50 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 60 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 70 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 80 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 90 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 100 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 110 nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth None nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 10 nombre Composants 9    training score: 0.77415 . valid score: 0.7209
# max_depth 20 nombre Composants 9    training score: 0.95825 . valid score: 0.7318
# max_depth 30 nombre Composants 9    training score: 0.9974 . valid score: 0.7254
# max_depth 40 nombre Composants 9    training score: 1.0 . valid score: 0.7239
# max_depth 50 nombre Composants 9    training score: 1.0 . valid score: 0.7247
# max_depth 60 nombre Composants 9    training score: 1.0 . valid score: 0.7201
# max_depth 70 nombre Composants 9    training score: 1.0 . valid score: 0.7238
# max_depth 80 nombre Composants 9    training score: 1.0 . valid score: 0.7243
# max_depth 90 nombre Composants 9    training score: 1.0 . valid score: 0.7242
# max_depth 100 nombre Composants 9    training score: 1.0 . valid score: 0.7217
# max_depth 110 nombre Composants 9    training score: 1.0 . valid score: 0.7231
# max_depth None nombre Composants 9    training score: 1.0 . valid score: 0.7239
# max_depth 10 nombre Composants 10    training score: 0.773 . valid score: 0.7205
# max_depth 20 nombre Composants 10    training score: 0.9643 . valid score: 0.7386
# max_depth 30 nombre Composants 10    training score: 0.9974 . valid score: 0.7346
# max_depth 40 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 50 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 60 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 70 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 80 nombre Composants 10    training score: 1.0 . valid score: 0.7335
# max_depth 90 nombre Composants 10    training score: 1.0 . valid score: 0.7333
# max_depth 100 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 110 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth None nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 10 nombre Composants 11    training score: 0.7761 . valid score: 0.727
# max_depth 20 nombre Composants 11    training score: 0.96685 . valid score: 0.7456
# max_depth 30 nombre Composants 11    training score: 0.99995 . valid score: 0.7369
# max_depth 40 nombre Composants 11    training score: 1.0 . valid score: 0.7368
# max_depth 50 nombre Composants 11    training score: 1.0 . valid score: 0.7369
# max_depth 60 nombre Composants 11    training score: 1.0 . valid score: 0.7368
# max_depth 70 nombre Composants 11    training score: 1.0 . valid score: 0.7368
# max_depth 80 nombre Composants 11    training score: 1.0 . valid score: 0.7378
# max_depth 90 nombre Composants 11    training score: 1.0 . valid score: 0.7384
# max_depth 100 nombre Composants 11    training score: 1.0 . valid score: 0.7363
# max_depth 110 nombre Composants 11    training score: 1.0 . valid score: 0.7354
# max_depth None nombre Composants 11    training score: 1.0 . valid score: 0.7361
# max_depth 10 nombre Composants 12    training score: 0.7788 . valid score: 0.7274
# max_depth 20 nombre Composants 12    training score: 0.9661 . valid score: 0.745
# max_depth 30 nombre Composants 12    training score: 0.9999 . valid score: 0.7377
# max_depth 40 nombre Composants 12    training score: 1.0 . valid score: 0.7398
# max_depth 20 nombre Composants 784    training score: 0.98695 . valid score: 0.7163
# max_depth 30 nombre Composants 784    training score: 0.9982 . valid score: 0.7164
# max_depth 40 nombre Composants 784    training score: 0.9995 . valid score: 0.714
# max_depth 50 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 60 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 70 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 80 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 90 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 100 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth 110 nombre Composants 784    training score: 1.0 . valid score: 0.7098
# max_depth None nombre Composants 784    training score: 1.0 . valid score: 0.7098

# %%
res1 = max(L) 
# printing result  
print ("The indices wise maximum number : " +  str(res1))
# Out:
# The indices wise maximum number : 0.6925

# %%
        preProc = sklearn.decomposition.PCA(n_components=20, copy=True)
        preProc.fit(X_train)
        X_train_Transformed = preProc.transform(X_train)
        X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

        ## classification
        clf = DecisionTreeClassifier(random_state=123,max_depth=60)
        clf.fit(X_train_Transformed, y_train)

        ## measure of performance
        scores = cross_val_score(clf, X_valid_Transformed, y_valid)
        print(scores)
        print("mean: {:.3f} (std: {:.3f})".format(scores.mean(),
                                                  scores.std()),
              end="\n\n")
# Out:
# [0.6625 0.7    0.7025 0.6775 0.715 ]
# mean: 0.691 (std: 0.019)

# %% [markdown]
# ### Part 1.3: `Ntrain+Nval=20000, Nvalid=10000`
#
# If you factored your code decently in the last questions, this should be very easy/fast to do. Ideally, it should be a couple of lines and a single function call. (For the core computation, excluding plots and presentation)
# - split the "train+validation" sets.
# - Find the best (max_depth, nComp_PCA) pair.
# - Measure the cross-validation error for this best pair. Are you surprised with the result?
#
# **Hint: to save compute time, you can use a smaller hyper-parameter search space, i.e. you can reduce the umber of values explored in your hyper-optimization.**

# %%
ratio_train= 0.333339
ratio_valid= 0.16667
X_train, y_train, X_valid, y_valid,n = split1(X, ratio_train, ratio_valid,ratio_test)
print(X_train.shape)
print(X_valid.shape)
# Out:
# (20000, 784)
# (10000, 784)

# %%
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
nComp_range = np.array(list(np.arange(1,50))+[50,100,200,400,783,784])
L=[]
for nC in nComp_range:

       for mp in max_depth:
                ## pre-processing 
                    preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
                    preProc.fit(X_train)
                    X_train_Transformed = preProc.transform(X_train)
                    X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

                ## classification
                    clf = DecisionTreeClassifier(random_state=123,max_depth=mp)
                    clf.fit(X_train_Transformed, y_train)

                ## measure of performance
                    trainscore = clf.score(X_train_Transformed,y_train)
                    validscore = clf.score(X_valid_Transformed,y_valid)
                    L.append( validscore)
                    print("max_depth", mp ,"nombre Composants", nC , "   training score:",trainscore, ". valid score:", validscore)
# Out:
# max_depth 10 nombre Composants 1    training score: 0.35005 . valid score: 0.2928
# max_depth 20 nombre Composants 1    training score: 0.5897 . valid score: 0.2589
# max_depth 30 nombre Composants 1    training score: 0.84595 . valid score: 0.2331
# max_depth 40 nombre Composants 1    training score: 0.97395 . valid score: 0.2201
# max_depth 50 nombre Composants 1    training score: 0.9986 . valid score: 0.2192
# max_depth 60 nombre Composants 1    training score: 0.99995 . valid score: 0.2195
# max_depth
ombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth None nombre Composants 8    training score: 1.0 . valid score: 0.7115
# max_depth 10 nombre Composants 9    training score: 0.77415 . valid score: 0.7209
# max_depth 20 nombre Composants 9    training score: 0.9583 . valid score: 0.7329
# max_depth 30 nombre Composants 9    training score: 0.99735 . valid score: 0.7252
# max_depth 40 nombre Composants 9    training score: 1.0 . valid score: 0.7239
# max_depth 50 nombre Composants 9    training score: 1.0 . valid score: 0.7242
# max_depth 60 nombre Composants 9    training score: 1.0 . valid score: 0.7247
# max_depth 70 nombre Composants 9    training score: 1.0 . valid score: 0.7242
# max_depth 80 nombre Composants 9    training score: 1.0 . valid score: 0.7201
# max_depth 90 nombre Composants 9    training score: 1.0 . valid score: 0.725
# max_depth 100 nombre Composants 9    training score: 1.0 . valid score: 0.7248
# max_depth 110 nombre Composants 9    training score: 1.0 . valid score: 0.7201
# max_depth None nombre Composants 9    training score: 1.0 . valid score: 0.7238
# max_depth 10 nombre Composants 10    training score: 0.773 . valid score: 0.7197
# max_depth 20 nombre Composants 10    training score: 0.96425 . valid score: 0.7409
# max_depth 30 nombre Composants 10    training score: 0.99905 . valid score: 0.7352
# max_depth 40 nombre Composants 10    training score: 1.0 . valid score: 0.7342
# max_depth 50 nombre Composants 10    training score: 1.0 . valid score: 0.7334
# max_depth 60 nombre Composants 10    training score: 1.0 . valid score: 0.7341
# max_depth 70 nombre Composants 10    training score: 1.0 . valid score: 0.7345
# max_depth 80 nombre Composants 10    training score: 1.0 . valid score: 0.7347
# max_depth 90 nombre Composants 10    training score: 1.0 . valid score: 0.735
# max_depth 100 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth 110 nombre Composants 10    training score: 1.0 . valid score: 0.7348
# max_depth None nombre Composants 10    training score: 1.0 . valid score: 0.7334
# max_depth 10 nombre Composants 11    training score: 0.77615 . valid score: 0.7269
# max_depth 20 nombre Composants 11    training score: 0.96665 . valid score: 0.7476
# max_depth 30 nombre Composants 11    training score: 0.99995 . valid score: 0.7373
# max_depth 40 nombre Composants 11    training score: 1.0 . valid score: 0.7381
# max_depth 50 nombre Composants 11    training score: 1.0 . valid score: 0.7368
# max_depth 60 nombre Composants 11    training score: 1.0 . valid score: 0.7346
# max_depth 70 nombre Composants 11    training score: 1.0 . valid score: 0.7364
# max_depth 80 nombre Composants 11    training score: 1.0 . valid score: 0.7368
# max_depth 90 nombre Composants 11    training score: 1.0 . valid score: 0.7366
# max_depth 100 nombre Composants 11    training score: 1.0 . valid score: 0.7366
# max_depth 110 nombre Composants 11    training score: 1.0 . valid score: 0.7386
# max_depth None nombre Composants 11    training score: 1.0 . valid score: 0.7371
# max_depth 10 nombre Composants 12    training score: 0.77875 . valid score: 0.7275
# max_depth 20 nombre Composants 12    training score: 0.9678 . valid score: 0.744
# max_depth 30 nombre Composants 12    training score: 1.0 . valid score: 0.7379
# max_depth 40 nombre Composants 12    training score: 1.0 . valid score: 0.7377
# max_depth 50 nombre Composants 12    training score: 1.0 . valid score: 0.7364
# max_depth 60 nombre Composants 12    training score: 1.0 . valid score: 0.7386
# max_depth 70 nombre Composants 12    training score: 1.0 . valid score: 0.7384
# max_depth 80 nombre Composants 12    training score: 1.0 . valid score: 0.735
# max_depth 40 nombre Composants 16    training score: 1.0 . valid score: 0.7452
# max_depth 50 nombre Composants 16    training score: 1.0 . valid score: 0.7464
# max_depth 60 nombre Composants 16    training score: 1.0 . valid score: 0.7452
# max_depth 70 nombre Composants 16    training score: 1.0 . valid score: 0.7433
# max_depth 80 nombre Composants 16    training score: 1.0 . valid score: 0.7474
# max_depth 90 nombre Composants 16    training score: 1.0 . valid score: 0.7475
# max_depth 100 nombre Composants 16    training score: 1.0 . valid score: 0.7446
# max_depth 110 nombre Composants 16    training score: 1.0 . valid score: 0.7457
# max_depth None nombre Composants 16    training score: 1.0 . valid score: 0.7455
# max_depth 10 nombre Composants 17    training score: 0.78555 . valid score: 0.7232
# max_depth 20 nombre Composants 17    training score: 0.9706 . valid score: 0.7581
# max_depth 30 nombre Composants 17    training score: 0.9998 . valid score: 0.7506
# max_depth 40 nombre Composants 17    training score: 1.0 . valid score: 0.7458
# max_depth 50 nombre Composants 17    training score: 1.0 . valid score: 0.751
# max_depth 60 nombre Composants 17    training score: 1.0 . valid score: 0.7447
# max_depth 70 nombre Composants 17    training score: 1.0 . valid score: 0.7478
# max_depth 80 nombre Composants 17    training score: 1.0 . valid score: 0.7511
# max_depth 90 nombre Composants 17    training score: 1.0 . valid score: 0.7508
# max_depth 100 nombre Composants 17    training score: 1.0 . valid score: 0.7503
# max_depth 110 nombre Composants 17    training score: 1.0 . valid score: 0.7505
# max_depth None nombre Composants 17    training score: 1.0 . valid score: 0.7478
# max_depth 10 nombre Composants 18    training score: 0.7811 . valid score: 0.7245
# max_depth 20 nombre Composants 18    training score: 0.9834 . valid score: 0.7508
# max_depth 30 nombre Composants 18    training score: 1.0 . valid score: 0.7515
# max_depth 40 nombre Composants 18    training score: 1.0 . valid score: 0.7542
# max_depth 50 nombre Composants 18    training score: 1.0 . valid score: 0.7498
# max_depth 60 nombre Composants 18    training score: 1.0 . valid score: 0.7537
# max_depth 70 nombre Composants 18    training score: 1.0 . valid score: 0.7476
# max_depth 80 nombre Composants 18    training score: 1.0 . valid score: 0.7525
# max_depth 90 nombre Composants 18    training score: 1.0 . valid score: 0.7486
# max_depth 100 nombre Composants 18    training score: 1.0 . valid score: 0.7519
# max_depth 110 nombre Composants 18    training score: 1.0 . valid score: 0.7509
# max_depth None nombre Composants 18    training score: 1.0 . valid score: 0.7508
# max_depth 10 nombre Composants 19    training score: 0.77905 . valid score: 0.7174
# max_depth 20 nombre Composants 19    training score: 0.9834 . valid score: 0.7542
# max_depth 30 nombre Composants 19    training score: 1.0 . valid score: 0.7484
# max_depth 40 nombre Composants 19    training score: 1.0 . valid score: 0.7569
# max_depth 50 nombre Composants 19    training score: 1.0 . valid score: 0.7512
# max_depth 60 nombre Composants 19    training score: 1.0 . valid score: 0.7533
# max_depth 70 nombre Composants 19    training score: 1.0 . valid score: 0.7485
# max_depth 80 nombre Composants 19    training score: 1.0 . valid score: 0.7494
# max_depth 90 nombre Composants 19    training score: 1.0 . valid score: 0.7534
# max_depth 100 nombre Composants 19    training score: 1.0 . valid score: 0.7475
# max_depth 110 nombre Composants 19    training score: 1.0 . valid score: 0.7509
# max_depth None nombre Composants 19    training score: 1.0 . valid score: 0.7542
# max_depth 10 nombre Composants 20    training score: 0.78255 . valid score: 0.723
# max_depth 20 nombre Composants 20    training score: 0.98265 . valid score: 0.7536
# max_depth 30 nombre Composants 20    training score: 0.99995 . valid score: 0.7502
# max_depth 40 nombre Composants 20    training score: 1.0 . valid score: 0.7516
# max_depth 50 nombre Composants 20    training score: 1.0 . valid score: 0.7503
# max_depth 60 nombre Composants 20    training score: 1.0 . valid score: 0.7501
# max_depth 70 nombre Composants 20    training score: 1.0 . valid score: 0.7497
# max_depth 80 nombre Composants 20    training score: 1.0 . valid score: 0.7527
# max_depth 90 nombre Composants 20    training score: 1.0 . valid score: 0.7513
# max_depth 100 nombre Composants 20    training score: 1.0 . valid score: 0.7523
# max_depth 110 nombre Composants 20    training score: 1.0 . valid score: 0.7556
# max_depth None nombre Composants 20    training score: 1.0 . valid score: 0.7498
# max_depth 10 nombre Composants 21    training score: 0.78195 . valid score: 0.7214
# max_depth 20 nombre Composants 21    training score: 0.9827 . valid score: 0.7624
# max_depth 30 nombre Composants 21    training score: 1.0 . valid score: 0.751
# max_depth 40 nombre Composants 21    training score: 1.0 . valid score: 0.7561
# max_depth 50 nombre Composants 21    training score: 1.0 . valid score: 0.7531
# max_depth 60 nombre Composants 21    training score: 1.0 . valid score: 0.7567
# max_depth 70 nombre Composants 21    training score: 1.0 . valid score: 0.7544
# max_depth 80 nombre Composants 21    training score: 1.0 . valid score: 0.7543
# max_depth 90 nombre Composants 21    training score: 1.0 . valid score: 0.7552
# max_depth 100 nombre Composants 21    training score: 1.0 . valid score: 0.7585
# max_depth 110 nombre Composants 21    training score: 1.0 . valid score: 0.7532
# max_depth None nombre Composants 21    training score: 1.0 . valid score: 0.7533
# max_depth 10 nombre Composants 22    training score: 0.78205 . valid score: 0.7235
# max_depth 20 nombre Composants 22    training score: 0.98325 . valid score: 0.7616
# max_depth 30 nombre Composants 22    training score: 0.99995 . valid score: 0.7585
# max_depth 40 nombre Composants 22    training score: 1.0 . valid score: 0.7554
# max_depth 50 nombre Composants 22    training score: 1.0 . valid score: 0.7572
# max_depth 60 nombre Composants 22    training score: 1.0 . valid score: 0.7502
# max_depth 70 nombre Composants 22    training score: 1.0 . valid score: 0.7551
# max_depth 80 nombre Composants 22    training score: 1.0 . valid score: 0.7558
# max_depth 90 nombre Composants 22    training score: 1.0 . valid score: 0.7558
# max_depth 100 nombre Composants 22    training score: 1.0 . valid score: 0.7503
# max_depth 110 nombre Composants 22    training score: 1.0 . valid score: 0.756
# max_depth None nombre Composants 22    training score: 1.0 . valid score: 0.7571
# max_depth 10 nombre Composants 23    training score: 0.78395 . valid score: 0.7235
# max_depth 20 nombre Composants 23    training score: 0.98395 . valid score: 0.7561
# max_depth 30 nombre Composants 23    training score: 0.9999 . valid score: 0.756
# max_depth 40 nombre Composants 23    training score: 1.0 . valid score: 0.7561
# max_depth 100 nombre Composants 100    training score: 1.0 . valid score: 0.7438
# max_depth 110 nombre Composants 100    training score: 1.0 . valid score: 0.7405
# max_depth None nombre Composants 100    training score: 1.0 . valid score: 0.738
# max_depth 10 nombre Composants 200    training score: 0.7979 . valid score: 0.7319
# max_depth 20 nombre Composants 200    training score: 0.9863 . valid score: 0.7405
# max_depth 30 nombre Composants 200    training score: 0.99765 . valid score: 0.737
# max_depth 40 nombre Composants 200    training score: 0.9997 . valid score: 0.7325
# max_depth 50 nombre Composants 200    training score: 1.0 . valid score: 0.7312
# max_depth 60 nombre Composants 200    training score: 1.0 . valid score: 0.7376
# max_depth 70 nombre Composants 200    training score: 1.0 . valid score: 0.7313
# max_depth 80 nombre Composants 200    training score: 1.0 . valid score: 0.7355
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-225-8a8d4ae614b5> in <module>
#       8                 ## pre-processing
#       9                     preProc = sklearn.decomposition.PCA(n_components=nC, copy=True)
# ---> 10                     preProc.fit(X_train)
#      11                     X_train_Transformed = preProc.transform(X_train)
#      12                     X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     349             Returns the instance itself.
#     350         """
# --> 351         self._fit(X)
#     352         return self
#     353
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     423             return self._fit_full(X, n_components)
#     424         elif self._fit_svd_solver in ['arpack', 'randomized']:
# --> 425             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#     426         else:
#     427             raise ValueError("Unrecognized svd_solver='{0}'"
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit_truncated(self, X, n_components, svd_solver)
#     540         elif svd_solver == 'randomized':
#     541             # sign flipping is done inside
# --> 542             U, S, V = randomized_svd(X, n_components=n_components,
#     543                                      n_iter=self.iterated_power,
#     544                                      flip_sign=True,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     347         M = M.T
#     348
# --> 349     Q = randomized_range_finder(
#     350         M, size=n_random, n_iter=n_iter,
#     351         power_iteration_normalizer=power_iteration_normalizer,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     232             Q = safe_sparse_dot(A.T, Q)
#     233         elif power_iteration_normalizer == 'LU':
# --> 234             Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#     235             Q, _ = linalg.lu(safe_sparse_dot(A.T, Q), permute_l=True)
#     236         elif power_iteration_normalizer == 'QR':
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
res1 = max(L) 
# printing result  
print ("The indices wise maximum number : " +  str(res1))
# Out:
# The indices wise maximum number : 0.7646

# %%
        preProc = sklearn.decomposition.PCA(n_components=27, copy=True)
        preProc.fit(X_train)
        X_train_Transformed = preProc.transform(X_train)
        X_valid_Transformed = preProc.transform(X_valid) ## applt the SAME transform to the validation data

        ## classification
        clf = DecisionTreeClassifier(random_state=123,max_depth=20)
        clf.fit(X_train_Transformed, y_train)

        ## measure of performance
        scores = cross_val_score(clf, X_valid_Transformed, y_valid)
        print(scores)
        print("mean: {:.3f} (std: {:.3f})".format(scores.mean(),
                                                  scores.std()),
              end="\n\n")
# Out:
# [0.731  0.738  0.7215 0.7355 0.717 ]
# mean: 0.729 (std: 0.008)

# %% [markdown]
# ### Part 1.4: The test (with `Ntest=10000`)
# Use your best model to make a prediction:
# - Which model do you prefer, among the 3 "best models" you have found? Why? How confident are you with your choice?
# - Using your `Ntest=10000` samples that you saved preciously (and NEVER used), compute the test error. How surprised are you with the result?
# - If you were asked by a client, "what is the level of accuracy you can achieve", what would be your answer ?

# %%
from sklearn.linear_model import LogisticRegression

X_train, y_train, X_valid, y_valid,n = split1(X, ratio_train, ratio_valid,ratio_test)
Xtest = LoadObject['test_images']
ytest = LoadObject['test_labels']
X_test  = Xtest[-n:].copy()
y_test  = ytest[-n:].copy()

preProc = sklearn.decomposition.PCA(n_components=27, copy=True)
preProc.fit(X_train)
X_train_Transformed = preProc.transform(X_train)
X_valid_Transformed = preProc.transform(X_valid)
X_test_Transformed  = preProc.transform(X_test)

clf = DecisionTreeClassifier(max_depth=20)
clf.fit(X_train_Transformed, y_train)
trainscore = clf.score(X_train_Transformed,y_train)
validscore = clf.score(X_valid_Transformed,y_valid)
testscore  = clf.score(X_test_Transformed,y_test)
print("   training score:",trainscore, ". valid score:", validscore)
print("test score: ", testscore)
# Out:
#    training score: 0.98015 . valid score: 0.76
# test score:  0.7527

# %%
from sklearn.linear_model import LogisticRegression

X_train, y_train, X_valid, y_valid,n = split1(X, ratio_train, ratio_valid,ratio_test)
Xtest = LoadObject['test_images']
ytest = LoadObject['test_labels']
X_test  = Xtest[-n:].copy()
y_test  = ytest[-n:].copy()

preProc = sklearn.decomposition.PCA(n_components=27, copy=True)
preProc.fit(X_train)
X_train_Transformed = preProc.transform(X_train)
X_valid_Transformed = preProc.transform(X_valid)
X_test_Transformed  = preProc.transform(X_test)
clf = LogisticRegression()
clf.fit(X_train_Transformed, y_train)
trainscore = clf.score(X_train_Transformed,y_train)
validscore = clf.score(X_valid_Transformed,y_valid)
testscore  = clf.score(X_test_Transformed,y_test)
print("   training score:",trainscore, ". valid score:", validscore)
print("test score: ", testscore)
# Out:
#    training score: 0.8166 . valid score: 0.813
# test score:  0.804
# C:\Users\dadinho\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
preProc = sklearn.decomposition.PCA(n_components=27, copy=True)
preProc.fit(X_train)
X_train_Transformed = preProc.transform(X_train)
X_valid_Transformed = preProc.transform(X_valid)
X_test_Transformed  = preProc.transform(X_test)
clf = DecisionTreeClassifier(max_depth=20)
clf.fit(X_train_Transformed, y_train)
y_pred = clf.predict(X_valid_Transformed)
score = balanced_accuracy_score(y_valid, y_pred)  # scoring
print("Balanced accuracy score: {}".format(score))
# Out:
# Balanced accuracy score: 0.760298425462633

# %%
preProc = sklearn.decomposition.PCA(n_components=27, copy=True)
preProc.fit(X_train)
X_train_Transformed = preProc.transform(X_train)
X_valid_Transformed = preProc.transform(X_valid)
X_test_Transformed  = preProc.transform(X_test)
clf = LogisticRegression()
clf.fit(X_train_Transformed, y_train)
y_pred = clf.predict(X_valid_Transformed)
score = balanced_accuracy_score(y_valid, y_pred)  # scoring
print("Balanced accuracy score: {}".format(score))
# Out:
# Balanced accuracy score: 0.8141267241632418
# C:\Users\dadinho\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Part 1.4 - Bonus question :
# - Compute also the cross validation error for the best hyper parameters choice with `N_train=200`
# - Plot the cross validation error as a function of ntrain= 200,2000,20000
# - People often say "let's just get more data". How efficient does that does seem to be ?

# %% [markdown]
# ## Part 2: make your own classifier !
#
# ## (about 5 points over 20 total)
#
# The multi-class percpetron can be implemented this way.
# We denote $K$ the number of classes, $N$ the number of (training) examples, $D$ the dimension of the data (after feature augmentation, at least with a "1" as first component).
#
# The **output** of the network *(not equal to the predicted label)*, can be taken as the **softmax** among the $K$ separating hyperplanes (each hyperplane $\vec{w}_k$ separates class $k$ from the others).
# $$ y_k^{(n)} = \text{softmax}\big( (\vec{w}_{k} \cdot \vec{x}^{(n)})_{k=1...K} \big) = \frac{ \exp(  \vec{w}_k\cdot\vec{x}^{(n)}   )}{\sum_\ell \exp(  \vec{w}_\ell\cdot\vec{x}^{(n)})}$$
# This output can be **interpreted as the probability** that example $x^{(n)}$ belongs to the class $k$, according the classifier's current parameters
# Indeed, one can easily check that for any $\vec{x}$, the sum of probabilities is indeed one : $\sum_k y_k = 1$.
# The **total output of the network** is a vector $\vec{y}^{(n)} = \begin{pmatrix}y_1^{(n)} \\ y_2^{(n)} \\ .. \\ y_K^{(n)} \end{pmatrix}$ (for the sample number $n$).
#
# The **true labels (ground truth)** of example $\vec{x}^{(n)}$ is then encoded as a one-hot vector, so that if the example is of the second class, it may be written: $\vec{t}^{n} = \begin{pmatrix} 0 \\ 1 \\ 0 \\ .. \\ 0 \end{pmatrix}$. (where $\vec{t}^{(n)}$ or $\vec{t}^{n}$ is for **T**ruth and is shorter to write than $\vec{y}^{GT,(n)}$). More generally, the components $t_{n,k}$ of vector $\vec{t}_n$ may be written using the Kronecker's delta: $t_{n,k} = \delta(k, k_{true}^n)$, where $k_{true}^n$ is the true class of example number $n$.
#
# From now on, **we drop the superscrip $a^{(n)}$ and instead write $a_n$ or just $a$**, when it's clear enough that the quantity $a$ relates to a single example, of generic index $n$. This helps to lighten the notations.
#
# The Loss function that we should use is called the **cross-entropy loss function**, and is:
#
# $$J = \frac1N \sum_n^N H(\vec{t}_{n}, \vec{y}_{n})$$
#
# where the cross-entropy is a non-symmetric function: $$H(\vec{t}_{n}, \vec{y}_{n}) = -\sum_k^K t_{n,k} \log (y_{n,k})$$
#
# Make sure you undersand all of the above. Write down the Loss function for the multi-class perceptron.
# ### Part 2.1
# - What are the parameters of the model ? **How many real numbers is that ?** Count them in terms of $N,K,D, etc$.
# - (3-4 points) **Derive the update steps for the gradient**. (you can get inspiration from TD4.1)
# - Some Hints:
#     - It is recommended to compute the quantity $\nabla_{w_\ell} y_k$ ($\ell\neq k$) and the quantity $\nabla_{w_k} y_k$. Try to express these simply, by recognizing $y$ when it appears. First treat the two cases separately, then try to unite the two cases in a single mathematical form, using Kronecker's delta : $\delta(i,j)= \{1$ if $i=j$, else $0\}$.
#     - When there is a sum $\sum_\ell f(w_\ell)$ and you derive with respect to $w_k$, the output only depends on the term $f(w_k)$
#     - In the sum above, $\sum_\ell f(w_\ell)$ the index $\ell$ is a "mute" index: you can use any letter for it. Be careful not to use a letter that already exists outside the sum ($\ell$ is like a local variable, don't use the same name for a "global variable" from outside the function !)
#     - For any functions $u,v$ that admit derivatives, $\partial_x \frac{u(x)}{v(x)} = \frac{u'(x)v(x)-u(x)v'(x)}{(v(x))^2}$. It extends to $\nabla_x$ without problem.
#     - $\nabla_x \exp(u(x)) =  \exp(u(x)) \nabla_x u(x)$.
#     - $\frac{a}{1+a} = 1- \frac{1}{1+a}$
#     - $\partial_x \log(u(x)) = \frac{u'(x)}{u(x)}$
#     - If you are too much blocked, you can ask me (via discord, in Private Message) for the solution of $\nabla_{w_k} y_k$ and/or the solution for $\nabla_{w_\ell} y_k$ ($\ell\neq k$).
#     - In the end, the update step for the parameters that you should find is : $$ \vec{w}_\ell \mapsto \vec{w}_\ell - \eta \frac1N \sum_n^N \vec{x}_n (\delta_{\ell, k_{true}^n}- y_{\ell,n})$$
#     - If you cannot find the equation above, you can just skip this question and use it to make your program.
#
#
#
# ### Part 2.2
# - (3 points) **Think up of all the functions you need to write**, and **put them in a class** (you can get inspiration from the correction of TP3.2) - first write a class skeleton, and **only then, write the methods** inside
# - Hints:
#     - there may be numerical errors (NaNs) because $\exp(..)$ is too large. You can ease this by noticing the following: for any positive constant $C$, we have $$\frac{ \exp( a_k  )}{\sum_\ell \exp (a_\ell) }  = \frac{C \exp( a_k  )}{C \sum_\ell \exp (a_\ell) }= \frac{\exp( a_k +\log C )}{\sum_\ell \exp (a_\ell +\log C) }$$
#     - with this trick, when your arguments in the softmax are too large, you can simply subtract a big constant $\log C$ from its argument, and this will reduce the chances of numerical error, without changing the result. It's a good idea to change the $w $'s with this kind of trick.
#     - it's a good idea to define the target labels (ground truth) data in one-hot vectors (as said above), compute them once and for all, and then you never have to compute them again. In practice, you may notice that for an example with label $k_{true}$, then the genreic component number of $k$ of the vector $\vec{t}$ reads: $t_{k} = \delta_{k, k_{true}}$
#     - the initial $w$ should be random (not all zeros), preferably, but not too big. A good idea is to have their dispersion be of order $1/D$ at most.
#
# For this question, the main goal is to make a theoretically-working, rather clean code, using numpy array-operations (`np.dot`) and not loops, as much as possible. If you manage to do that, you will most likely have a working code (and fast code!)
# - (1 point) Test your algorithm on Fashion-MNIST: make a train / validation / test split , fit the model, compute the cross-val error, and the test error. Don't waste time on optimizing hyper-parameters (just take an $\eta$ small enough that you kind of converge. The goal is really to prove that your algorithm does not always crash :)

# %%
## remark:
import numpy as np
print(np.exp(100))
# Out:
# 2.6881171418161356e+43

# %%
print(np.exp(800)- np.exp(800))
# Out:
# nan
# <ipython-input-261-b2a98dd2d170>:1: RuntimeWarning: overflow encountered in exp
#   print(np.exp(800)- np.exp(800))
# <ipython-input-261-b2a98dd2d170>:1: RuntimeWarning: invalid value encountered in double_scalars
#   print(np.exp(800)- np.exp(800))
